# %%
import math
import pandas as pd
import numpy as np
from datetime import datetime
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
customers_df = pd.read_csv("../data/olist_customers_dataset.csv")
geoloc_df = pd.read_csv("../data/olist_geolocation_dataset.csv")
order_items_df = pd.read_csv("../data/olist_order_items_dataset.csv")
order_payments_df = pd.read_csv("../data/olist_order_payments_dataset.csv")
order_reviews_df = pd.read_csv("../data/olist_order_reviews_dataset.csv")
order_df = pd.read_csv("../data/olist_orders_dataset.csv")
products_df = pd.read_csv("../data/olist_products_dataset.csv")
sellers_df = pd.read_csv("../data/olist_sellers_dataset.csv")
product_category_name_translation_df = pd.read_csv("../data/product_category_name_translation.csv")

# %%
order_df.dropna(inplace=True)

# %%
def infer_datetime(s):
    return datetime.strptime(s, "%Y-%m-%d %H:%M:%S")

def get_lat_lng(uid:str, uid_type:str):
    
    if uid_type == "seller":
        lat = sellers_df[sellers_df.seller_id == uid]['s_lat'].values[0]
        lng = sellers_df[sellers_df.seller_id == uid]['s_lng'].values[0]
    
    elif uid_type == "customer":
        lat = customers_df[customers_df.customer_id == uid]['c_lat'].values[0]
        lng = customers_df[customers_df.customer_id == uid]['c_lng'].values[0]
    return lat,lng

def get_lat_lon_dist(lat1,lon1,lat2,lon2):
    try:
        return round(math.acos((math.sin(math.radians(lat1)) * math.sin(math.radians(lat2))) + 
                (math.cos(math.radians(lat1)) * math.cos(math.radians(lat2))) * 
                (math.cos(math.radians(lon2) - math.radians(lon1)))) * 6371, 3)
    except ValueError:
        print(lat1,lon1,lat2,lon2)
        return 0

def get_customer_seller_dist(customer_id, seller_id):
    lat1, lng1 = get_lat_lng(customer_id, 'customer')
    seller_dists = []
    for s in seller_id:
        lat2, lng2 = get_lat_lng(s, 'seller')
        seller_dists.append(get_lat_lon_dist(lat1, lng1, lat2, lng2))
    return max(seller_dists)

def get_business_days(start_date, end_date):
    return sum([date.isoweekday() <=5 for date in pd.date_range(infer_datetime(start_date), infer_datetime(end_date))])

# %%
products_df['product_volumn'] = products_df.apply(lambda r: r.product_length_cm*r.product_height_cm*r.product_width_cm, axis=1)

order_items_df = order_items_df.merge(products_df, on="product_id")

grouped_order_items_df = order_items_df.groupby(['order_id']).agg({'product_id': ['count', 'nunique'], 
                                          'seller_id': ['count', 'nunique', 'unique'],
                                          'price':'sum', 'freight_value':'sum',
                                          'product_volumn':'sum', 'product_weight_g':'sum'}
                                        ).reset_index()

grouped_order_items_df.columns = ['_'.join([col1,col2]) if col2 else col1 for col1,col2 in grouped_order_items_df.columns.values]

grouped_order_items_df.reset_index(drop=True, inplace=True)
# grouped_order_items_df

# %%
full_df = pd.merge(left = order_df, right=grouped_order_items_df, on='order_id', how='left')

# %%
full_df['order_approved_after(s)'] = full_df.apply(lambda r: (infer_datetime(r.order_approved_at) - infer_datetime(r.order_purchase_timestamp)).total_seconds(), axis=1)

# %%
full_df['order_delivered_carrier_after_approval(s)'] = full_df.apply(lambda r: (infer_datetime(r.order_delivered_carrier_date) - infer_datetime(r.order_approved_at)).total_seconds(), axis=1)

# %%
grouped_order_payments_df = order_payments_df.groupby(['order_id']).agg({'payment_sequential': 'max', 
                                          'payment_type': lambda x: pd.Series(list(x)).value_counts().to_dict(),
                                          'payment_installments':'sum', 
                                          'payment_value':'sum'}
                                        ).reset_index()

# %%
grouped_order_payments_df['credit_card_payments'] = grouped_order_payments_df.payment_type.apply(lambda x: x.get('credit_card',0))
grouped_order_payments_df['boleto_payments'] = grouped_order_payments_df.payment_type.apply(lambda x: x.get('boleto',0))
grouped_order_payments_df['voucher_payments'] = grouped_order_payments_df.payment_type.apply(lambda x: x.get('voucher',0))
grouped_order_payments_df['debit_card_payments'] = grouped_order_payments_df.payment_type.apply(lambda x: x.get('debit_card',0))
grouped_order_payments_df['not_defined_payments'] = grouped_order_payments_df.payment_type.apply(lambda x: x.get('not_defined',0))

# %%
full_df = pd.merge(left = full_df, right=grouped_order_payments_df, on='order_id', how='left')

# %%
geoloc_df['geo_id'] = geoloc_df.geolocation_zip_code_prefix.astype("str")+geoloc_df.geolocation_city + geoloc_df.geolocation_state
customers_df['geo_id'] = customers_df['customer_zip_code_prefix'].astype("str")+customers_df.customer_city+customers_df.customer_state
sellers_df['geo_id'] = sellers_df['seller_zip_code_prefix'].astype("str")+sellers_df.seller_city+sellers_df.seller_state

geoloc_df_grouped = geoloc_df.groupby("geo_id").agg({"geolocation_lat":"mean",
                                "geolocation_lng":"mean"})
geoloc_df_grouped.reset_index(inplace=True)

customers_df = customers_df.merge(geoloc_df_grouped, on='geo_id', how='left').rename({'geolocation_lat': 'c_lat', 'geolocation_lng': 'c_lng'}, axis=1)

sellers_df = sellers_df.merge(geoloc_df_grouped, on='geo_id', how='left').rename({'geolocation_lat': 's_lat', 'geolocation_lng': 's_lng'}, axis=1)

# %%
full_df['seller_lat_lon'] = full_df.progress_apply(lambda r: np.mean([get_lat_lng(sid, 'seller') for sid in r.seller_id_unique],axis=0), axis=1)

full_df['cust_lat_lon'] = full_df.progress_apply(lambda r: get_lat_lng(r.customer_id, 'customer'), axis=1)

full_df['seller_cust_dist'] = full_df.progress_apply(lambda r: get_lat_lon_dist(r.cust_lat_lon[0],r.cust_lat_lon[1],
                                                                                r.seller_lat_lon[0],r.seller_lat_lon[1]), axis=1)
# Out:
#   0%|          | 0/96461 [00:00<?, ?it/s]
#   0%|          | 0/96461 [00:00<?, ?it/s]
#   0%|          | 0/96461 [00:00<?, ?it/s]
# -24.95918428429227 -53.462644000056976 -24.95918428429227 -53.462644000056976

# %%
full_df['late_delivery'] = order_df.apply(lambda r: infer_datetime(r.order_delivered_customer_date) > infer_datetime(r.order_estimated_delivery_date), axis=1)
full_df['late_delivery'].value_counts(normalize=True)
# Out:
# late_delivery
# False    0.918823
# True     0.081177
# Name: proportion, dtype: float64

# %%
full_df.dropna(inplace=True)
full_df.reset_index(drop=True, inplace=True)

# %%
full_df['late_delivery'].value_counts(normalize=True)
# Out:
# late_delivery
# False    0.918718
# True     0.081282
# Name: proportion, dtype: float64

# %%
full_df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'product_id_count', 'product_id_nunique', 'seller_id_count',
#        'seller_id_nunique', 'seller_id_unique', 'price_sum',
#        'freight_value_sum', 'product_volumn_sum', 'product_weight_g_sum',
#        'order_approved_after(s)', 'order_delivered_carrier_after_approval(s)',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value', 'credit_card_payments', 'boleto_payments',
#        'voucher_payments', 'debit_card_payments', 'not_defined_payments',
#        'seller_lat_lon', 'cust_lat_lon', 'seller_cust_dist', 'late_delivery'],
#       dtype='object')

# %%
full_df['deliverd_to_carrier_after(business_days)'] = full_df.apply(lambda r: get_business_days(start_date = r.order_purchase_timestamp,
                                                                                                end_date = r.order_delivered_carrier_date), axis=1)

# %%
full_df['deliverd_to_carrier_after(business_days)'].value_counts()
# Out:
# deliverd_to_carrier_after(business_days)
# 2     27286
# 1     25339
# 3     14820
# 4      8074
# 5      4615
# 0      3266
# 6      2288
# 7      1381
# 8       897
# 9       621
# 10      511
# 11      374
# 12      261
# 13      208
# 14      151
# 15      119
# 16       99
# 17       77
# 18       70
# 19       41
# 20       38
# 21       26
# 22       21
# 29       20
# 24       20
# 23       20
# 25       18
# 30       16
# 27       12
# 28       10
# 31       10
# 26        9
# 34        7
# 33        4
# 36        4
# 32        3
# 40        2
# 75        1
# 39        1
# 78        1
# 90        1
# 37        1
# 47        1
# 45        1
# 44        1
# Name: count, dtype: int64

# %%
full_df['deliverd_to_customer_after(business_days)'] = full_df.apply(lambda r: get_business_days(start_date = r.order_delivered_carrier_date,
                                                                                                 end_date = r.order_delivered_customer_date), axis=1)

# %%
full_df['deliverd_to_carrier_after(business_days)'].value_counts()
# Out:
# deliverd_to_carrier_after(business_days)
# 2     27286
# 1     25339
# 3     14820
# 4      8074
# 5      4615
# 0      3266
# 6      2288
# 7      1381
# 8       897
# 9       621
# 10      511
# 11      374
# 12      261
# 13      208
# 14      151
# 15      119
# 16       99
# 17       77
# 18       70
# 19       41
# 20       38
# 21       26
# 22       21
# 29       20
# 24       20
# 23       20
# 25       18
# 30       16
# 27       12
# 28       10
# 31       10
# 26        9
# 34        7
# 33        4
# 36        4
# 32        3
# 40        2
# 75        1
# 39        1
# 78        1
# 90        1
# 37        1
# 47        1
# 45        1
# 44        1
# Name: count, dtype: int64

# %%
# order_payments_df[order_payments_df.order_id == "fa65dad1b0e818e3ccc5cb0e39231352"]

# %%
full_df.to_csv("olist_merged.csv", index=False)

# %% [markdown]
# ### Model 1 : Predict the number of business days to deliver the order to carrier

# %%
model1_data = full_df.loc[:, ['order_id','product_id_count','product_id_nunique','seller_id_count',
                              'seller_id_nunique','price_sum','freight_value_sum','product_volumn_sum', 
                              'product_weight_g_sum', 'order_approved_after(s)', 'payment_type', 'payment_installments', 
                              'seller_cust_dist','deliverd_to_carrier_after(business_days)']]

# %%
model1_data
# Out:
#                                order_id  product_id_count  product_id_nunique  \
# 0      e481f51cbdc54678b7cc49136f2d6af7                 1                   1
# 1      47770eb9100c2d0c44946d9cf07ec65d                 1                   1
# 2      949d5b44dbf5de918fe9c16f97b45f8a                 1                   1
# 3      ad21c59c0840e6cb83a9ceb5573f8159                 1                   1
# 4      a4591c265e18cb1dcee52889e2d8acc3                 1                   1
# ...                                 ...               ...                 ...
# 90741  9c5dedf39a927c1b2549525ed64a053c                 1                   1
# 90742  63943bddc261676b46f01ca7ac2f7bd8                 1                   1
# 90743  83c1379a015df1e13d02aae0204711ab                 1                   1
# 90744  11c177c8e97725db2631073c19f07b62                 2                   1
# 90745  66dea50a8b16d9b4dee7af250b4be1a5                 1                   1
#
#        seller_id_count  seller_id_nunique  price_sum  freight_value_sum  \
# 0                    1                  1      29.99               8.72
# 1                    1                  1     159.90              19.22
# 2                    1                  1      45.00              27.20
# 3                    1                  1      19.90               8.72
# 4                    1                  1     147.90              27.36
# ...                ...                ...        ...                ...
# 90741                1                  1      72.00              13.08
# 90742                1                  1     174.90              20.10
# 90743                1                  1     205.99              65.02
# 90744                2                  1     359.98              81.18
# 90745                1                  1      68.50              18.36
#
#        product_volumn_sum  product_weight_g_sum  order_approved_after(s)  \
# 0                  1976.0                 500.0                    642.0
# 1                  9576.0                 420.0                    994.0
# 2                  6000.0                 450.0                   1073.0
# 3                 11475.0                 250.0                   3710.0
# 4                 42250.0                7150.0                    788.0
# ...                   ...                   ...                      ...
# 90741              5148.0                1175.0                      0.0
# 90742             16000.0                4950.0                    699.0
# 90743             63360.0               13300.0                   1053.0
# 90744             16000.0               13100.0                    474.0
# 90745              1680.0                 150.0                  51778.0
#
#        payment_type  payment_installments  seller_cust_dist  \
# 0               3.0                   3.0            18.581
# 1               1.0                   3.0           514.448
# 2               1.0                   1.0          1822.109
# 3               1.0                   1.0            29.678
# 4               1.0                   6.0           411.394
# ...             ...                   ...               ...
# 90741           1.0                   3.0            69.777
# 90742           1.0                   3.0           474.100
# 90743           1.0                   5.0           967.794
# 90744           1.0                   4.0           370.346
# 90745           1.0                   1.0           631.259
#
#        deliverd_to_carrier_after(business_days)
# 0                                             3
# 1                                             1
# 2                                             2
# 3                                             1
# 4                                             1
# ...                                         ...
# 90741                                         2
# 90742                                         2
# 90743                                         1
# 90744                                         4
# 90745                                         2
#
# [90746 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
num_cols = ['price_sum','freight_value_sum', 'product_volumn_sum', 'product_weight_g_sum', 'order_approved_after(s)',
            'seller_cust_dist']

# %%
scalar = StandardScaler()
model1_data.loc[:,(num_cols)] = scalar.fit_transform(model1_data.loc[:,(num_cols)])

# %%
model1_data
# Out:
#                                order_id  product_id_count  product_id_nunique  \
# 0      e481f51cbdc54678b7cc49136f2d6af7                 1                   1
# 1      47770eb9100c2d0c44946d9cf07ec65d                 1                   1
# 2      949d5b44dbf5de918fe9c16f97b45f8a                 1                   1
# 3      ad21c59c0840e6cb83a9ceb5573f8159                 1                   1
# 4      a4591c265e18cb1dcee52889e2d8acc3                 1                   1
# ...                                 ...               ...                 ...
# 90741  9c5dedf39a927c1b2549525ed64a053c                 1                   1
# 90742  63943bddc261676b46f01ca7ac2f7bd8                 1                   1
# 90743  83c1379a015df1e13d02aae0204711ab                 1                   1
# 90744  11c177c8e97725db2631073c19f07b62                 2                   1
# 90745  66dea50a8b16d9b4dee7af250b4be1a5                 1                   1
#
#        seller_id_count  seller_id_nunique  price_sum  freight_value_sum  \
# 0                    1                  1  -0.508937          -0.649233
# 1                    1                  1   0.113900          -0.160615
# 2                    1                  1  -0.436973           0.210735
# 3                    1                  1  -0.557312          -0.649233
# 4                    1                  1   0.056368           0.218181
# ...                ...                ...        ...                ...
# 90741                1                  1  -0.307525          -0.446340
# 90742                1                  1   0.185816          -0.119664
# 90743                1                  1   0.334873           1.970692
# 90744                2                  1   1.073159           2.722698
# 90745                1                  1  -0.324305          -0.200635
#
#        product_volumn_sum  product_weight_g_sum  order_approved_after(s)  \
# 0               -0.508171             -0.392535                -0.490818
# 1               -0.252900             -0.409606                -0.486070
# 2               -0.373012             -0.403204                -0.485005
# 3               -0.189115             -0.445881                -0.449438
# 4                0.844567              1.026474                -0.488849
# ...                   ...                   ...                      ...
# 90741           -0.401629             -0.248500                -0.499477
# 90742           -0.037128              0.557027                -0.490049
# 90743            1.553617              2.338791                -0.485275
# 90744           -0.037128              2.296114                -0.493084
# 90745           -0.518113             -0.467220                 0.198885
#
#        payment_type  payment_installments  seller_cust_dist  \
# 0               3.0                   3.0         -0.980211
# 1               1.0                   3.0         -0.144942
# 2               1.0                   1.0          2.057761
# 3               1.0                   1.0         -0.961518
# 4               1.0                   6.0         -0.318533
# ...             ...                   ...               ...
# 90741           1.0                   3.0         -0.893973
# 90742           1.0                   3.0         -0.212907
# 90743           1.0                   5.0          0.618701
# 90744           1.0                   4.0         -0.387676
# 90745           1.0                   1.0          0.051821
#
#        deliverd_to_carrier_after(business_days)
# 0                                             3
# 1                                             1
# 2                                             2
# 3                                             1
# 4                                             1
# ...                                         ...
# 90741                                         2
# 90742                                         2
# 90743                                         1
# 90744                                         4
# 90745                                         2
#
# [90746 rows x 14 columns]

# %%
X = model1_data.drop(['order_id', 'deliverd_to_carrier_after(business_days)'], axis=1)
y = model1_data.loc[:,'deliverd_to_carrier_after(business_days)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,  random_state=314)

# %%
y_cut = pd.cut(y,bins=[0,1,3,6,11,9999],
               include_lowest=True,
               right=False,
               labels=['same_day','1_2_days','3_5_days','6_10_days','more_than_10_days']
              )

X_train, X_test, y_train, y_test = train_test_split(X, y_cut, test_size = 0.20,  random_state=314)

# %%
rf_classifier = RandomForestClassifier(max_depth=10)
rf_classifier.fit(X_train, y_train)
y_train_pred = rf_classifier.predict(X_train)
y_test_pred = rf_classifier.predict(X_test)

# %%
print(f"Train F1 Score {f1_score(y_train, y_train_pred, average='micro')}")
print(f"Test F1 Score {f1_score(y_test, y_test_pred, average='micro')}")
# Out:
# Train F1 Score 0.6346768416992672
# Test F1 Score 0.6155922865013774

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error

# %%
def fit_model(model, X_train, y_train):
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    return model, y_train_pred, y_test_pred

# %%
lr_regressor = LinearRegression()
lr_regressor.fit(X_train, y_train)
y_train_pred = lr_regressor.predict(X_train)
y_test_pred = lr_regressor.predict(X_test)

rounder = lambda t: np.round(t)
y_train_pred = rounder(y_train_pred)
y_test_pred = rounder(y_test_pred)

# %%
print(f"Train F1 Score {mean_squared_error(y_train, y_train_pred)}")
print(f"Test F1 Score {mean_squared_error(y_test, y_test_pred)}")
# Out:
# Train F1 Score 6.284519808253898
# Test F1 Score 6.385289256198347

# %%
rf_regressor, y_train_pred, y_test_pred = fit_model(RandomForestRegressor(), X_train, y_train)

# %%
print(f"Train F1 Score {mean_squared_error(y_train, y_train_pred)}")
print(f"Test F1 Score {mean_squared_error(y_test, y_test_pred)}")
# Out:
# Train F1 Score 0.8017706099509615
# Test F1 Score 5.746675173553719

# %%
from xgboost import XGBRegressor

# %%
xgb_regressor, y_train_pred, y_test_pred = fit_model(XGBRegressor(), X_train, y_train)
print(f"Train F1 Score {mean_squared_error(y_train, y_train_pred)}")
print(f"Test F1 Score {mean_squared_error(y_test, y_test_pred)}")
# Out:
# Train F1 Score 4.034952653169647
# Test F1 Score 5.695081868431639

# %%
rounder = lambda t: np.round(t)
y_train_pred = rounder(y_train_pred)
y_test_pred = rounder(y_test_pred)
print(f"Train F1 Score {mean_squared_error(y_train, y_train_pred)}")
print(f"Test F1 Score {mean_squared_error(y_test, y_test_pred)}")
# Out:
# Train F1 Score 4.11128712325748
# Test F1 Score 5.780716253443527

# %%
delayed_delivery_data = full_df.loc[:, ['order_id','product_id_count','product_id_nunique','seller_id_count',
                                        'seller_id_nunique','price_sum','freight_value_sum','product_volumn_sum', 
                                        'product_weight_g_sum', 'order_approved_after(s)', 
                                        'order_delivered_carrier_after_approval(s)',  'payment_type', 
                                        'payment_installments', 'payment_value','seller_cust_dist','late_delivery']]

# %%
delayed_delivery_data
# Out:
#                                order_id  product_id_count  product_id_nunique  \
# 0      e481f51cbdc54678b7cc49136f2d6af7                 1                   1
# 1      47770eb9100c2d0c44946d9cf07ec65d                 1                   1
# 2      949d5b44dbf5de918fe9c16f97b45f8a                 1                   1
# 3      ad21c59c0840e6cb83a9ceb5573f8159                 1                   1
# 4      a4591c265e18cb1dcee52889e2d8acc3                 1                   1
# ...                                 ...               ...                 ...
# 90741  9c5dedf39a927c1b2549525ed64a053c                 1                   1
# 90742  63943bddc261676b46f01ca7ac2f7bd8                 1                   1
# 90743  83c1379a015df1e13d02aae0204711ab                 1                   1
# 90744  11c177c8e97725db2631073c19f07b62                 2                   1
# 90745  66dea50a8b16d9b4dee7af250b4be1a5                 1                   1
#
#        seller_id_count  seller_id_nunique  price_sum  freight_value_sum  \
# 0                    1                  1      29.99               8.72
# 1                    1                  1     159.90              19.22
# 2                    1                  1      45.00              27.20
# 3                    1                  1      19.90               8.72
# 4                    1                  1     147.90              27.36
# ...                ...                ...        ...                ...
# 90741                1                  1      72.00              13.08
# 90742                1                  1     174.90              20.10
# 90743                1                  1     205.99              65.02
# 90744                2                  1     359.98              81.18
# 90745                1                  1      68.50              18.36
#
#        product_volumn_sum  product_weight_g_sum  order_approved_after(s)  \
# 0                  1976.0                 500.0                    642.0
# 1                  9576.0                 420.0                    994.0
# 2                  6000.0                 450.0                   1073.0
# 3                 11475.0                 250.0                   3710.0
# 4                 42250.0                7150.0                    788.0
# ...                   ...                   ...                      ...
# 90741              5148.0                1175.0                      0.0
# 90742             16000.0                4950.0                    699.0
# 90743             63360.0               13300.0                   1053.0
# 90744             16000.0               13100.0                    474.0
# 90745              1680.0                 150.0                  51778.0
#
#        order_delivered_carrier_after_approval(s)  payment_type  \
# 0                                       204465.0           3.0
# 1                                        17677.0           1.0
# 2                                       323640.0           1.0
# 3                                        77165.0           1.0
# 4                                       146871.0           1.0
# ...                                          ...           ...
# 90741                                    91438.0           1.0
# 90742                                   123125.0           1.0
# 90743                                   107290.0           1.0
# 90744                                   323922.0           1.0
# 90745                                    39091.0           1.0
#
#        payment_installments  payment_value  seller_cust_dist late_delivery
# 0                       3.0          38.71            18.581         False
# 1                       3.0         179.12           514.448         False
# 2                       1.0          72.20          1822.109         False
# 3                       1.0          28.62            29.678         False
# 4                       6.0         175.26           411.394         False
# ...                     ...            ...               ...           ...
# 90741                   3.0          85.08            69.777         False
# 90742                   3.0         195.00           474.100         False
# 90743                   5.0         271.01           967.794         False
# 90744                   4.0         441.16           370.346         False
# 90745                   1.0          86.86           631.259          True
#
# [90746 rows x 16 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

# %%
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
y_train_pred = rf_classifier.predict(X_train)
y_test_pred = rf_classifier.predict(X_test)

# %%
print(f"Train F1 Score {f1_score(y_train, y_train_pred)}")
print(f"Test F1 Score {f1_score(y_test, y_test_pred)}")
# Out:
# Train F1 Score 0.999744092809008
# Test F1 Score 0.0

# %%
rf_classifier = RandomForestClassifier(max_depth=20, class_weight='balanced')
rf_classifier.fit(X_train, y_train)
y_train_pred = rf_classifier.predict(X_train)
y_test_pred = rf_classifier.predict(X_test)

# %%
print(f"Train F1 Score {f1_score(y_train, y_train_pred)}")
print(f"Test F1 Score {f1_score(y_test, y_test_pred)}")
# Out:
# Train F1 Score 0.9046403099410055
# Test F1 Score 0.016568047337278107

# %%
full_df.customer_id.value_counts()
# Out:
# customer_id
# 9ef432eb6251297304e76186b10a928d    1
# 4ff9d132fe2c07793f39e324e86f0383    1
# a51921054a93c2d99f085ebee1817c81    1
# 82eb0f700864871ddc51572601014ba4    1
# b0d798d76605a085ed8b3a196da24b24    1
#                                    ..
# 41719c34900034230304c9266e5b6713    1
# 2d0ef7c75a0403680d304c62ba3b2721    1
# f86ef9a9bd878f3c22617b38ea06d3ff    1
# dbad14e1cbdb1f106ac9b2b3f4b89d15    1
# edb027a75a1449115f6b43211ae02a24    1
# Name: count, Length: 90746, dtype: int64

# %%
# full_df['same_day_delivery'] = full_df.apply(lambda r: datetime.strftime(infer_datetime(r.order_purchase_timestamp), format="%Y-%m-%d") ==
#                                              datetime.strftime(infer_datetime(r.order_delivered_customer_date), format="%Y-%m-%d"), axis=1)

# %%
test_sample = full_df.sample(50)

# %%
test_sample['seller_cust_dist'] = test_sample.progress_apply(lambda r: get_customer_seller_dist(r.customer_id, r.seller_id_unique), axis=1)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
test_sample
# Out:
#                                order_id                       customer_id  \
# 83491  12fd4ba303cb9951f45b3ce9b6ba764b  8b4639324f4de248b5196a893aaad0eb
# 51970  86f353da4086de44a6acd7faf109e47d  dcdd2033f19ef7bcacdf2e683c8f2e65
# 71396  293fe99febcd4990b7ab31c5cd2abfd5  407d685edcbff0e025864e271eb2e5b7
# 45322  03e6de4517499ee6aaae7d9004799504  650b8d581bd67d61888f8ea779e34e7c
# 43312  a3a0cfe6661449e2d725b5b1ff658d84  2e57ca0d2c4b939fd528fe677acca228
# 94616  9286a7cc933d6e2099098e4ae057e5dc  ed8097f13c2401a34f2d78cf43260846
# 1031   241a57ba96decfbe134f5c84f585f57f  b8426f2cfe27d43ae8077d218a3622ad
# 84659  b997ce40f469fbcd2e163e6a2df04de8  e193e498ca7e4b73bf1d55f365b6f64b
# 8349   d3f58dcb7705f30c2257940517740287  cbcfae7b60710216bbea3d587a83af2e
# 18963  0b3f84ce012f341897587c6e4e73f68e  bd2e650f73a529c3dd307b6eec01393e
# 58338  8931f3424faa278c3e45084b9a3db2a5  59606088131f94d6e5cd764404377a6c
# 61426  bd22679f67e770fe1a872d8d1b85f985  1d6f3ef21f84fb799b1b00d422c6c578
# 85619  eef26c46e9fd031a373c429edc171b59  e2da939d767d0b2bad9ff78463b23256
# 59320  b7c0da6da0a4987fd0b793c77ebbb06a  f48021d46a7c5b0a77b16ea28981cfd8
# 5759   cc4687e4e102c1c8c606a5a0a8e475db  079e85f42f5af80c74240b97b7a4dee1
# 4949   932da4ab5c1239381360b912976ef417  e4b702a6340fe28a885500871b9d13a8
# 61559  ca7af64c0e6b1a6fc563832581a7c544  895edce5f11d005be5c28f6efe45d984
# 32478  151137bf7ab537c1a2da6bba1368d87d  8678ce9bb3f23410f28b6caa0813528a
# 63824  c9b660037dee4fa3a452b22ff921916f  e3d0615c4b434d03fd22c8599ab02195
# 81156  72db4956f094dff247d75dd6735f2400  aba8474309cce50f19ab29cea5ff6b20
# 28790  93c5ca94a86b96968decd0a16f17ef60  a30188dc4c8e67dcf05b313855039c05
# 53769  4806c15e687faabdb46ca2643cfcfa6e  4dec66cb2a457ca68a6b8e431d375a11
# 34426  b6df8ec45b7a0b36bae45fcac237f298  07073537c7394038818895e9cca2ab06
# 53778  4c612311c4c424c8ccf682de9b443659  78337577a7b3160393cf5f5e69f13d52
# 28523  f9604c62f4691fd43013cd1e6489e332  d3ca3a344d5f960ad6733ccc5b27005c
# 11301  92e3415f60fec80f07ebca939434c3a7  85163f5cd854d552b1627f12e52721fc
# 45493  790a2b1cebf279ed28bf91f4fe91478c  4ea820653bf7274276f572b286e50726
# 9767   f5469d54daa9f43486f2d4ab2b154406  cd7d7b4d8d652f2a44de11261fb5f749
# 23678  afc7d4ca1aa5030cdb685010ed145c70  82f6a7b92692b8658dcde6117abdea48
# 51283  34ce0ca85ae4e7d8cad0c61a10236321  eed993e8f243582c4f4609155e4dad75
# 85472  7e429b54c3c0a8b4206c8d42b6a55bf8  687b0e4d0c667dc8d20a300c8b0635d1
# 42194  3fce76a41d913dedb8f211a38fa0a8b8  c8ecf49c62e0943b4a44bad2af3f0e5f
# 46494  4a757189692c5edda3f4491ed110f223  73bcc45a89640ee54f87e2a4b9fb5821
# 81776  563a48e2c7312a1aeefbbae15eb17521  92e944661c1d4cbed22d076c56a0c811
# 83841  4296801e936343a5f6a38e29143c0f88  8b26e9f4e8dadffe40b101bea7634b9b
# 22570  15360da03a0a021fc0e712a2d11f3020  9fa6f373ffbaf4c8dacd572551406374
# 23937  5a5ebfbbca639e25e63f09761e953a44  a37ac9cb206c694271dba8da8c53c576
# 62739  3d5bdaa6f74a7d0bb1d4040b9cb9aa3b  61bfe54a45dc8c5cd242f47818eb0964
# 18156  0775e96080c552251cd76472d32e0c83  b301495c792065eaa3c4fa6f11bb0407
# 85810  3b29577134414b4e92667a99da76dbd1  a92da5f6ab925f1b45c83cef38a87fe0
# 42690  3c32b5ee0d19331febeea91a6fbf37c8  279a09411f28ae559c302075deafbae5
# 40519  7093b7177380b099eb92c2ab46c6f10e  f0c20eb716fdd6eee9527ec291b182e6
# 91550  4014ecd96ac1d06f8cca3ac729c389ff  e6bc52e3e443d2ac256c764962bf842f
# 581    2042abeefae68e63a8aa30edd4b0eb48  a37a37235d7b3be3e2f95747ca589bda
# 91372  2e5e827b80515bc21c042a5181e32ec5  a1d3d78e83da30d70783ff40f8c9067e
# 51465  b924597838a7ba1e624e99fbd62cc560  f20577a98700e15cb66175781ca8433d
# 94628  efe5d91d523dcb8acc12b56d74523979  a925b24d158b3313f54502e1c01806f7
# 12591  3db932725b90f4f388d2e361b0f1247e  fc34108ccfb5cd9c569ae7531fe9435c
# 22400  84b33f3ecdf8f82df2db1517f0f44396  9619f561d67cb918bf4a6d608a04febc
# 52661  84436e09e2da8d549e06fa56fa0b74e0  256f06cb1d10d7427f8ab3d96b873cab
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 83491    delivered      2018-03-18 21:13:46  2018-03-18 21:30:28
# 51970    delivered      2017-07-13 22:29:41  2017-07-13 22:45:07
# 71396    delivered      2017-08-20 16:22:25  2017-08-20 16:35:13
# 45322    delivered      2018-05-16 18:39:40  2018-05-16 18:57:28
# 43312    delivered      2018-07-10 11:52:24  2018-07-10 12:05:32
# 94616    delivered      2018-03-27 03:01:08  2018-03-28 02:50:14
# 1031     delivered      2017-11-10 17:21:48  2017-11-10 17:35:33
# 84659    delivered      2017-03-25 14:30:46  2017-03-25 14:45:11
# 8349     delivered      2017-05-02 03:48:26  2017-05-02 04:02:33
# 18963    delivered      2018-06-30 21:48:45  2018-07-01 21:50:01
# 58338    delivered      2018-02-06 13:08:49  2018-02-06 13:35:10
# 61426    delivered      2018-03-23 02:36:09  2018-03-23 02:50:21
# 85619    delivered      2017-06-19 21:27:05  2017-06-19 21:35:29
# 59320    delivered      2017-10-31 21:51:02  2017-10-31 22:06:03
# 5759     delivered      2017-10-31 20:13:41  2017-11-01 20:25:18
# 4949     delivered      2018-06-20 11:46:06  2018-06-20 12:05:58
# 61559    delivered      2017-12-16 22:16:03  2017-12-16 22:32:29
# 32478    delivered      2017-09-05 13:52:21  2017-09-05 14:05:17
# 63824    delivered      2017-11-12 14:33:08  2017-11-12 14:46:53
# 81156    delivered      2018-01-26 08:01:35  2018-01-26 08:19:07
# 28790    delivered      2018-02-14 20:32:40  2018-02-19 08:35:21
# 53769    delivered      2018-02-18 18:41:59  2018-02-18 18:55:34
# 34426    delivered      2017-12-20 06:08:35  2017-12-22 02:38:56
# 53778    delivered      2018-08-09 06:35:43  2018-08-10 03:24:35
# 28523    delivered      2017-06-19 10:10:22  2017-06-19 10:25:15
# 11301    delivered      2017-01-27 10:29:59  2017-01-27 10:41:54
# 45493    delivered      2018-05-25 09:27:20  2018-05-26 02:32:00
# 9767     delivered      2017-08-18 13:21:50  2017-08-22 04:07:08
# 23678    delivered      2018-01-02 10:19:18  2018-01-02 10:31:31
# 51283    delivered      2018-07-17 14:16:29  2018-07-17 14:30:21
# 85472    delivered      2017-07-12 15:09:25  2017-07-13 03:03:56
# 42194    delivered      2017-05-01 16:51:20  2017-05-06 21:33:35
# 46494    delivered      2018-01-20 21:38:05  2018-01-20 22:01:21
# 81776    delivered      2018-03-27 16:37:52  2018-03-28 12:55:20
# 83841    delivered      2017-11-06 08:38:45  2017-11-06 08:50:26
# 22570    delivered      2017-08-30 13:09:34  2017-08-30 13:25:11
# 23937    delivered      2018-05-02 23:54:28  2018-05-04 07:51:50
# 62739    delivered      2017-04-18 12:22:00  2017-04-18 12:35:22
# 18156    delivered      2017-09-06 01:29:21  2017-09-06 01:44:00
# 85810    delivered      2018-01-19 14:29:39  2018-01-19 14:57:13
# 42690    delivered      2018-08-03 10:13:50  2018-08-03 10:30:15
# 40519    delivered      2017-04-09 15:49:31  2017-04-09 16:01:57
# 91550    delivered      2018-08-05 01:59:32  2018-08-07 04:35:22
# 581      delivered      2018-05-26 23:52:17  2018-05-27 23:49:24
# 91372    delivered      2017-09-10 15:51:25  2017-09-11 16:05:09
# 51465    delivered      2018-03-08 16:12:38  2018-03-08 16:55:55
# 94628    delivered      2018-06-28 08:00:25  2018-06-28 08:10:39
# 12591    delivered      2017-08-01 19:11:08  2017-08-01 19:53:53
# 22400    delivered      2018-06-18 20:50:11  2018-06-18 21:17:49
# 52661    delivered      2017-12-12 18:00:32  2017-12-12 19:09:57
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 83491          2018-03-19 22:46:39           2018-04-10 22:14:46
# 51970          2017-07-21 18:57:19           2017-08-01 18:37:43
# 71396          2017-08-22 10:33:43           2017-08-24 18:43:51
# 45322          2018-05-17 13:45:00           2018-05-29 14:36:55
# 43312          2018-07-11 08:40:00           2018-07-20 19:55:33
# 94616          2018-03-28 20:03:12           2018-04-02 20:05:18
# 1031           2017-11-14 16:47:09           2017-11-22 00:22:48
# 84659          2017-03-28 11:42:59           2017-04-03 16:53:51
# 8349           2017-05-02 14:48:05           2017-05-05 16:43:38
# 18963          2018-07-03 11:15:00           2018-07-12 15:28:49
# 58338          2018-02-08 19:28:37           2018-02-24 01:16:41
# 61426          2018-03-23 19:46:51           2018-03-28 18:16:30
# 85619          2017-06-22 10:25:50           2017-07-03 12:09:45
# 59320          2017-11-01 15:52:18           2017-11-09 23:46:45
# 5759           2017-11-03 22:25:53           2017-11-16 19:37:04
# 4949           2018-06-20 12:36:00           2018-06-28 19:37:51
# 61559          2017-12-18 21:22:50           2017-12-26 22:04:16
# 32478          2017-09-11 18:11:49           2017-09-18 18:59:39
# 63824          2017-11-13 19:17:05           2017-11-24 19:54:28
# 81156          2018-01-26 21:36:38           2018-02-01 23:29:37
# 28790          2018-02-19 22:49:02           2018-02-22 00:48:42
# 53769          2018-02-19 18:52:11           2018-03-14 20:16:24
# 34426          2017-12-22 17:53:49           2018-01-12 23:58:42
# 53778          2018-08-10 15:10:00           2018-08-16 00:28:30
# 28523          2017-06-19 20:51:50           2017-06-26 17:21:55
# 11301          2017-01-31 11:50:54           2017-02-02 17:43:58
# 45493          2018-05-29 14:20:00           2018-06-07 20:50:31
# 9767           2017-08-23 18:04:26           2017-09-18 22:27:02
# 23678          2018-01-09 20:59:26           2018-01-15 23:33:49
# 51283          2018-07-17 15:40:00           2018-07-23 11:56:25
# 85472          2017-07-14 17:45:44           2017-07-26 12:46:47
# 42194          2017-05-03 16:10:14           2017-05-09 08:50:07
# 46494          2018-01-23 18:10:26           2018-02-08 21:13:37
# 81776          2018-03-29 00:34:24           2018-04-07 11:28:51
# 83841          2017-11-09 19:09:29           2017-12-05 21:38:54
# 22570          2017-08-31 22:29:44           2017-09-05 21:57:01
# 23937          2018-05-04 15:03:00           2018-05-08 22:21:46
# 62739          2017-04-19 09:43:16           2017-05-02 14:24:18
# 18156          2017-09-12 17:51:42           2017-09-19 14:33:10
# 85810          2018-01-23 00:36:35           2018-01-24 19:41:44
# 42690          2018-08-03 11:38:00           2018-08-15 02:04:44
# 40519          2017-04-10 13:48:25           2017-04-26 12:53:28
# 91550          2018-08-08 13:44:00           2018-08-10 23:57:50
# 581            2018-05-28 14:09:00           2018-05-30 15:48:56
# 91372          2017-09-12 18:43:51           2017-09-15 16:33:29
# 51465          2018-03-14 00:51:40           2018-03-16 19:07:19
# 94628          2018-06-29 14:05:00           2018-06-30 17:16:15
# 12591          2017-08-03 17:29:24           2017-08-14 18:16:09
# 22400          2018-06-19 13:17:00           2018-06-25 13:18:46
# 52661          2017-12-13 18:21:55           2017-12-28 16:32:23
#
#       order_estimated_delivery_date  target  product_id_count  ...  \
# 83491           2018-04-13 00:00:00   False                 1  ...
# 51970           2017-08-10 00:00:00   False                 1  ...
# 71396           2017-09-05 00:00:00   False                 1  ...
# 45322           2018-06-26 00:00:00   False                 1  ...
# 43312           2018-08-01 00:00:00   False                 1  ...
# 94616           2018-04-13 00:00:00   False                 1  ...
# 1031            2017-12-01 00:00:00   False                 1  ...
# 84659           2017-04-19 00:00:00   False                 1  ...
# 8349            2017-05-29 00:00:00   False                 1  ...
# 18963           2018-08-01 00:00:00   False                 1  ...
# 58338           2018-03-07 00:00:00   False                 1  ...
# 61426           2018-04-06 00:00:00   False                 1  ...
# 85619           2017-07-19 00:00:00   False                 1  ...
# 59320           2017-11-23 00:00:00   False                 1  ...
# 5759            2017-12-06 00:00:00   False                 1  ...
# 4949            2018-07-13 00:00:00   False                 1  ...
# 61559           2018-01-23 00:00:00   False                 1  ...
# 32478           2017-10-03 00:00:00   False                 2  ...
# 63824           2017-12-04 00:00:00   False                 1  ...
# 81156           2018-02-19 00:00:00   False                 1  ...
# 28790           2018-02-26 00:00:00   False                 1  ...
# 53769           2018-03-12 00:00:00    True                 3  ...
# 34426           2018-01-24 00:00:00   False                 1  ...
# 53778           2018-08-27 00:00:00   False                 1  ...
# 28523           2017-07-07 00:00:00   False                 1  ...
# 11301           2017-03-03 00:00:00   False                 1  ...
# 45493           2018-07-13 00:00:00   False                 1  ...
# 9767            2017-09-20 00:00:00   False                 1  ...
# 23678           2018-02-08 00:00:00   False                 2  ...
# 51283           2018-07-31 00:00:00   False                 1  ...
# 85472           2017-08-03 00:00:00   False                 2  ...
# 42194           2017-05-25 00:00:00   False                 2  ...
# 46494           2018-02-20 00:00:00   False                 1  ...
# 81776           2018-04-23 00:00:00   False                 1  ...
# 83841           2017-11-30 00:00:00    True                 1  ...
# 22570           2017-09-20 00:00:00   False                 1  ...
# 23937           2018-05-14 00:00:00   False                 1  ...
# 62739           2017-05-11 00:00:00   False                 1  ...
# 18156           2017-09-29 00:00:00   False                 1  ...
# 85810           2018-02-09 00:00:00   False                 3  ...
# 42690           2018-08-23 00:00:00   False                 1  ...
# 40519           2017-05-12 00:00:00   False                 1  ...
# 91550           2018-08-10 00:00:00    True                 2  ...
# 581             2018-06-20 00:00:00   False                 1  ...
# 91372           2017-09-27 00:00:00   False                 1  ...
# 51465           2018-03-20 00:00:00   False                 1  ...
# 94628           2018-07-12 00:00:00   False                 1  ...
# 12591           2017-08-23 00:00:00   False                 1  ...
# 22400           2018-07-11 00:00:00   False                 1  ...
# 52661           2018-01-05 00:00:00   False                 1  ...
#
#        freight_value_sum  product_volumn_sum  product_weight_g_sum  \
# 83491              22.85              3024.0                 247.0
# 51970              53.48             87696.0               16800.0
# 71396               7.78              4500.0                 200.0
# 45322              23.98              4352.0                 767.0
# 43312              27.22              6750.0                1250.0
# 94616              12.79               816.0                 200.0
# 1031               15.79              3328.0                 275.0
# 84659              14.11              1980.0                 150.0
# 8349               19.45              8000.0                2200.0
# 18963              60.20             58682.0               10050.0
# 58338              17.15             12250.0                 800.0
# 61426               8.88             13858.0                 700.0
# 85619              17.17             25000.0                 300.0
# 59320              38.47              8000.0                5950.0
# 5759               51.79             19344.0                2800.0
# 4949               18.15             15750.0                1500.0
# 61559              17.67             11520.0                1600.0
# 32478              32.34             26400.0                1400.0
# 63824              14.10               640.0                 250.0
# 81156              12.44              8000.0                1400.0
# 28790              33.63            147108.0                7625.0
# 53769             257.28             95472.0               19725.0
# 34426              37.96             12000.0                 450.0
# 53778              12.79               704.0                 167.0
# 28523              11.85              2816.0                 150.0
# 11301              10.96              1386.0                 400.0
# 45493              51.59             26450.0                5300.0
# 9767               66.85             31416.0               10150.0
# 23678              33.74             26026.0                2100.0
# 51283              13.71              1056.0                 150.0
# 85472              37.60             27090.0                2450.0
# 42194              36.20              8000.0                5000.0
# 46494              86.21            114000.0               19050.0
# 81776              19.32             12006.0                 675.0
# 83841              15.28              4664.0                 700.0
# 22570              14.10              8736.0                 400.0
# 23937               7.39              2640.0                 200.0
# 62739              14.76              5967.0                 250.0
# 18156              12.55             45000.0                1650.0
# 85810              36.75             14739.0                1050.0
# 42690              22.92               352.0                 200.0
# 40519              27.38             14400.0                1700.0
# 91550              17.64              6000.0                1000.0
# 581                12.14              7616.0                1700.0
# 91372              12.69             18000.0                 350.0
# 51465               8.40               816.0                 300.0
# 94628              12.82             11470.0                1323.0
# 12591              15.10              3705.0                 100.0
# 22400              13.55              2040.0                 320.0
# 52661              14.20              3744.0                 400.0
#
#       order_approved_after(s)  order_delivered_carrier_after_approval(s)  \
# 83491                  1002.0                                    90971.0
# 51970                   926.0                                   677532.0
# 71396                   768.0                                   151110.0
# 45322                  1068.0                                    67652.0
# 43312                   788.0                                    74068.0
# 94616                 85746.0                                    61978.0
# 1031                    825.0                                   342696.0
# 84659                   865.0                                   248268.0
# 8349                    847.0                                    38732.0
# 18963                 86476.0                                   134699.0
# 58338                  1581.0                                   194007.0
# 61426                   852.0                                    60990.0
# 85619                   504.0                                   219021.0
# 59320                   901.0                                    63975.0
# 5759                  87097.0                                   180035.0
# 4949                   1192.0                                     1802.0
# 61559                   986.0                                   168621.0
# 32478                   776.0                                   533192.0
# 63824                   825.0                                   102612.0
# 81156                  1052.0                                    47851.0
# 28790                388961.0                                    51221.0
# 53769                   815.0                                    86197.0
# 34426                160221.0                                    54893.0
# 53778                 74932.0                                    42325.0
# 28523                   893.0                                    37595.0
# 11301                   715.0                                   349740.0
# 45493                 61480.0                                   301680.0
# 9767                 312318.0                                   136638.0
# 23678                   733.0                                   642475.0
# 51283                   832.0                                     4179.0
# 85472                 42871.0                                   139308.0
# 42194                448935.0                                  -278601.0
# 46494                  1396.0                                   245345.0
# 81776                 73048.0                                    41944.0
# 83841                   701.0                                   296343.0
# 22570                   937.0                                   119073.0
# 23937                115042.0                                    25870.0
# 62739                   802.0                                    76074.0
# 18156                   879.0                                   576462.0
# 85810                  1654.0                                   293962.0
# 42690                   985.0                                     4065.0
# 40519                   746.0                                    78388.0
# 91550                182150.0                                   119318.0
# 581                   86227.0                                    51576.0
# 91372                 87224.0                                    95922.0
# 51465                  2597.0                                   460545.0
# 94628                   614.0                                   107661.0
# 12591                  2565.0                                   164131.0
# 22400                  1658.0                                    57551.0
# 52661                  4165.0                                    83518.0
#
#        payment_sequential  payment_type  payment_installments  payment_value  \
# 83491                 1.0           1.0                   3.0          58.75
# 51970                 7.0           7.0                   9.0         263.47
# 71396                 1.0           1.0                   4.0          42.77
# 45322                 1.0           1.0                   2.0         173.88
# 43312                 1.0           1.0                   2.0          92.12
# 94616                 1.0           1.0                   1.0          34.69
# 1031                  1.0           1.0                   1.0          46.79
# 84659                 1.0           1.0                   3.0          32.10
# 8349                  1.0           1.0                   5.0         208.35
# 18963                 1.0           1.0                   5.0         198.20
# 58338                 1.0           1.0                   4.0         215.15
# 61426                 1.0           1.0                   2.0          72.78
# 85619                 1.0           1.0                   5.0         121.17
# 59320                 1.0           1.0                  10.0         128.46
# 5759                  1.0           1.0                   8.0        1391.79
# 4949                  1.0           1.0                   1.0          68.15
# 61559                 3.0           3.0                   3.0          77.66
# 32478                 1.0           1.0                   3.0         150.34
# 63824                 1.0           1.0                   2.0          63.10
# 81156                 1.0           1.0                   2.0         147.34
# 28790                 1.0           1.0                   1.0         323.53
# 53769                 1.0           1.0                   5.0         708.48
# 34426                 1.0           1.0                   1.0          96.96
# 53778                 1.0           1.0                   1.0          27.69
# 28523                 1.0           1.0                   1.0          51.75
# 11301                 1.0           1.0                   1.0          40.95
# 45493                 1.0           1.0                   1.0         185.59
# 9767                  1.0           1.0                   1.0         556.75
# 23678                 1.0           1.0                   1.0         211.74
# 51283                 1.0           1.0                   2.0         163.61
# 85472                 1.0           1.0                   1.0         479.42
# 42194                 1.0           1.0                   6.0         124.10
# 46494                 1.0           1.0                   8.0         785.21
# 81776                 1.0           1.0                   1.0          55.27
# 83841                 1.0           1.0                   9.0          91.18
# 22570                 1.0           1.0                   5.0          54.09
# 23937                 1.0           1.0                   1.0          25.29
# 62739                 1.0           1.0                   1.0          98.76
# 18156                 1.0           1.0                   1.0          72.45
# 85810                 1.0           1.0                   1.0         357.75
# 42690                 1.0           1.0                   1.0          51.92
# 40519                 1.0           1.0                   3.0         157.28
# 91550                 1.0           1.0                   1.0          53.62
# 581                   1.0           1.0                   1.0         162.04
# 91372                 1.0           1.0                   1.0          42.58
# 51465                 1.0           1.0                   1.0          38.39
# 94628                 1.0           1.0                   2.0          87.62
# 12591                 1.0           1.0                   2.0          25.00
# 22400                 1.0           1.0                   1.0         140.55
# 52661                 1.0           1.0                   1.0          78.70
#
#        seller_cust_dist
# 83491          2218.914
# 51970           324.296
# 71396            34.106
# 45322           729.701
# 43312          1687.832
# 94616            28.523
# 1031            882.187
# 84659           350.575
# 8349            912.222
# 18963           311.062
# 58338           199.745
# 61426            54.988
# 85619          1444.362
# 59320           307.856
# 5759           2022.893
# 4949            755.465
# 61559           334.390
# 32478          1054.350
# 63824           878.696
# 81156           275.755
# 28790           189.390
# 53769           326.710
# 34426          2386.561
# 53778           416.069
# 28523           171.154
# 11301            48.500
# 45493          1051.028
# 9767           1298.127
# 23678           815.874
# 51283           334.400
# 85472           431.877
# 42194           316.000
# 46494          1074.782
# 81776           721.327
# 83841           726.704
# 22570           352.870
# 23937            28.542
# 62739           350.661
# 18156           698.663
# 85810           292.548
# 42690          2365.869
# 40519          1814.092
# 91550            66.486
# 581             140.152
# 91372           299.854
# 51465             9.246
# 94628            14.465
# 12591           411.135
# 22400           296.056
# 52661           352.886
#
# [50 rows x 25 columns]

# %%
test_sample[test_sample['seller_cust_dist'] == test_sample['seller_cust_dist'].max()].iloc[0]
# Out:
# order_id                                       c1b86a370f491b37cc3adb8ef0a21fe5
# customer_id                                    5c5689c7522389a8ff3e28ead3a4cd55
# order_status                                                          delivered
# order_purchase_timestamp                                    2017-03-21 10:09:06
# order_approved_at                                           2017-03-26 23:32:51
# order_delivered_carrier_date                                2017-03-30 16:32:07
# order_delivered_customer_date                               2017-04-20 08:05:23
# order_estimated_delivery_date                               2017-04-28 00:00:00
# target                                                                    False
# product_id_count                                                              1
# product_id_nunique                                                            1
# seller_id_count                                                               1
# seller_id_nunique                                                             1
# seller_id_unique                             [87142160b41353c4e5fca2360caf6f92]
# price_sum                                                                 105.0
# freight_value_sum                                                         41.85
# product_volumn_sum                                                      24000.0
# product_weight_g_sum                                                     2800.0
# order_approved_after(s)                                                480225.0
# order_delivered_carrier_after_approval(s)                              320356.0
# payment_sequential                                                          1.0
# payment_type                                                                1.0
# payment_installments                                                        1.0
# payment_value                                                            146.85
# seller_cust_dist                                                        2556.61
# Name: 90087, dtype: object

# %%
test_sample[test_sample['seller_cust_dist'] == test_sample['seller_cust_dist'].min()].iloc[0]
# Out:
# order_id                                       d55ece0f3afa9b57b5a78038efddbbbc
# customer_id                                    f027649d8f2a7b182522d5da3cd4f010
# order_status                                                          delivered
# order_purchase_timestamp                                    2017-05-22 17:20:34
# order_approved_at                                           2017-05-24 02:50:18
# order_delivered_carrier_date                                2017-05-24 09:44:28
# order_delivered_customer_date                               2017-05-25 10:40:49
# order_estimated_delivery_date                               2017-06-06 00:00:00
# target                                                                    False
# product_id_count                                                              1
# product_id_nunique                                                            1
# seller_id_count                                                               1
# seller_id_nunique                                                             1
# seller_id_unique                             [f181738b150df1f37cb0bd72e705b193]
# price_sum                                                                 219.0
# freight_value_sum                                                         17.58
# product_volumn_sum                                                      27520.0
# product_weight_g_sum                                                     9800.0
# order_approved_after(s)                                                120584.0
# order_delivered_carrier_after_approval(s)                               24850.0
# payment_sequential                                                          1.0
# payment_type                                                                1.0
# payment_installments                                                        1.0
# payment_value                                                            236.58
# seller_cust_dist                                                          8.204
# Name: 21645, dtype: object

# %%
customers_df[customers_df.customer_id == "948b29e24216a05fea13a18d8db45ea5"]
# Out:
#                             customer_id                customer_unique_id  \
# 84222  948b29e24216a05fea13a18d8db45ea5  6740f8899f3c70b5b08b2e0bad37e567
#
#        customer_zip_code_prefix       customer_city customer_state  \
# 84222                     83252  ilha dos valadares             PR
#
#                           geo_id      c_lat     c_lng
# 84222  83252ilha dos valadaresPR  42.184003 -8.723762

# %%
sellers_df[sellers_df.seller_id == "0417b067eeab773d2f7061a726dc477f"]
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 2658  0417b067eeab773d2f7061a726dc477f                   89288
#
#            seller_city seller_state                   geo_id      s_lat  \
# 2658  sao bento do sul           SC  89288sao bento do sulSC -26.232399
#
#           s_lng
# 2658 -49.411493

# %%
get_lat_lng('948b29e24216a05fea13a18d8db45ea5', 'customer')
# Out:
# (42.18400274298598, -8.723762147513938)

# %%
get_lat_lng('0417b067eeab773d2f7061a726dc477f', 'seller')
# Out:
# (-26.23239898377447, -49.41149336148303)

# %%
get_lat_lon_dist(42.18400274298598, -8.723762147513938, -26.23239898377447, -49.41149336148303)
# Out:
# 8677.912

# %%
full_df[full_df.customer_id == "5c5689c7522389a8ff3e28ead3a4cd55"].iloc[0]
# Out:
# order_id                                              c1b86a370f491b37cc3adb8ef0a21fe5
# customer_id                                           5c5689c7522389a8ff3e28ead3a4cd55
# order_status                                                                 delivered
# order_purchase_timestamp                                           2017-03-21 10:09:06
# order_approved_at                                                  2017-03-26 23:32:51
# order_delivered_carrier_date                                       2017-03-30 16:32:07
# order_delivered_customer_date                                      2017-04-20 08:05:23
# order_estimated_delivery_date                                      2017-04-28 00:00:00
# target                                                                           False
# product_id_count                                                                     1
# product_id_nunique                                                                   1
# seller_id_count                                                                      1
# seller_id_nunique                                                                    1
# seller_id_unique                                    [87142160b41353c4e5fca2360caf6f92]
# price_sum                                                                        105.0
# freight_value_sum                                                                41.85
# product_volumn_sum                                                             24000.0
# product_weight_g_sum                                                            2800.0
# order_approved_after(s)                                                       480225.0
# order_delivered_carrier_after_approval(s)                                     320356.0
# payment_sequential                                                                 1.0
# payment_type                                                                       1.0
# payment_installments                                                               1.0
# payment_value                                                                   146.85
# seller_lat_lon                               [-30.008181567706295, -51.20130443913637]
# cust_lat_lon                                 (-7.5314749353251536, -46.04310515312331)
# seller_cust_dist                                                               2556.61
# Name: 90087, dtype: object

# %%
full_df[full_df['seller_cust_dist'] == full_df['seller_cust_dist'].max()].iloc[0]
# Out:
# order_id                                             8ad3f1d0f96992e43566c4c82c9f6c58
# customer_id                                          948b29e24216a05fea13a18d8db45ea5
# order_status                                                                delivered
# order_purchase_timestamp                                          2018-07-17 21:25:29
# order_approved_at                                                 2018-07-17 21:35:17
# order_delivered_carrier_date                                      2018-07-18 13:08:00
# order_delivered_customer_date                                     2018-08-14 04:04:40
# order_estimated_delivery_date                                     2018-08-03 00:00:00
# target                                                                           True
# product_id_count                                                                    1
# product_id_nunique                                                                  1
# seller_id_count                                                                     1
# seller_id_nunique                                                                   1
# seller_id_unique                                   [0417b067eeab773d2f7061a726dc477f]
# price_sum                                                                       67.99
# freight_value_sum                                                                25.6
# product_volumn_sum                                                            53751.0
# product_weight_g_sum                                                           4900.0
# order_approved_after(s)                                                         588.0
# order_delivered_carrier_after_approval(s)                                     55963.0
# payment_sequential                                                                1.0
# payment_type                                                                      1.0
# payment_installments                                                              1.0
# payment_value                                                                   93.59
# seller_lat_lon                               [-26.23239898377447, -49.41149336148303]
# cust_lat_lon                                  (42.18400274298598, -8.723762147513938)
# seller_cust_dist                                                             8677.912
# Name: 705, dtype: object
